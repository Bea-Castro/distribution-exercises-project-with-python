# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
#FUNCIONES DISTRIBUCIÓN NORMAL

# 1. Función de densidad probabildiad (pdf)
def dens_prob(x,mean=0, std=1):
    resultado_pdf= dens_prob.pdf(x,mean,std)  

# 2. Función de distribución acumulativa (CDF)
def distr_acu(x,mean=0,std=1):
    resultado_cdf= distr_acu.cdf(x,mean=0, std=1)
  
# FUNCIONES DISTRIBUCION UNIFORME

# 1. Función de densidad probabildiad (pdf)
def uniform_dens_prob(x,mean=0, std=1):
    resultado_unif_pdf= uniform_dens_prob.pdf(x,mean,std)
    
# 2. Función de distribución acumulativa (CDF)
def uniform_distr_acu(x,mean=0,std=1):
    resultado_unif_cdf = uniform_distr_acu.cdf(x,mean=0, std=1)

# %%
import numpy as np
from scipy.stats import norm, uniform

# DISTRIBUCIÓN NORMAL (importamos las funciones de scipy para graficar)
# Funciones para distribución normal

# 1. Función de densidad probabilidad (PDF) para distribución normal
def dens_prob(x, mean=0, std=1):
    return norm.pdf(x, loc=mean, scale=std)

# 2. Función de distribución acumulativa (CDF) para distribución normal
def distr_acu(x, mean=0, std=1):
    return norm.cdf(x, loc=mean, scale=std)


# GRÁFICOS DISTRIBUCIÓN NORMAL
x = np.linspace(-25, 25, 100)  # Más puntos para una curva más suave
pdf = dens_prob(x, mean=0, std=1)
cdf = distr_acu(x, mean=0, std=1)

plt.figure(figsize=(10, 5))

# Graficar PDF
plt.subplot(1, 2, 1)
plt.plot(x, pdf, label='PDF', color='blue')
plt.title('Función de Densidad de Probabilidad (PDF)')
plt.xlabel('x')
plt.ylabel('Densidad')
plt.grid()
plt.legend()

# Graficar CDF
plt.subplot(1, 2, 2)
plt.plot(x, cdf, label='CDF', color='green')
plt.title('Función de Distribución Acumulativa (CDF)')
plt.xlabel('x')
plt.ylabel('Probabilidad Acumulada')
plt.grid()
plt.legend()

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %%
# DISTRIBUCÓN UNIFORME

# 1. Función de densidad probabilidad (PDF) para distribución uniforme
def uniform_dens_prob(x, low=0, high=1):
    return uniform.pdf(x, loc=low, scale=high-low)

# 2. Función de distribución acumulativa (CDF) para distribución uniforme
def uniform_distr_acu(x, low=0, high=1):
    return uniform.cdf(x, loc=low, scale=high-low)

pdf = dens_prob(x, mean=0, std=1)
cdf = distr_acu(x, mean=0, std=1)

# GRAFICOS DISTRIBUCIÓN UNIFORME
plt.figure(figsize=(10, 5))

# Gráfico de la PDF
plt.subplot(1, 2, 1)
plt.plot(x, pdf, label='PDF', color='red')
plt.title('Función de Densidad de Probabilidad (PDF)')
plt.xlabel('x')
plt.ylabel('Densidad')
plt.grid()
plt.legend()

# Gráfico de la CDF
plt.subplot(1, 2, 2)
plt.plot(x, cdf, label='CDF', color='purple')
plt.title('Función de Distribución Acumulativa (CDF)')
plt.xlabel('x')
plt.ylabel('Probabilidad Acumulada')
plt.grid()
plt.legend()

# Mostrar los gráficos
plt.tight_layout()
plt.show()
